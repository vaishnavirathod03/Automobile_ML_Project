# %%
# importing libraries for EDA

import pandas as pd
import numpy as np

# %%
# loading data into dataframe

# sep='separator_symbol'--> it separates the data with the help of seperator symbol

ad=pd.read_csv('Automobile_data.csv')

# %%
# displaying the data

ad
# Out:
#       symboling     car-name fuel-type aspiration num-of-doors   body-style  \
# 0           NaN  alfa-romero       gas        std          two  convertible
# 1           NaN  alfa-romero       gas        std          two  convertible
# 2           NaN  alfa-romero       gas        std          two    hatchback
# 3           NaN         audi       gas        std         four        sedan
# 4           NaN         audi       gas        std         four        sedan
# ...         ...          ...       ...        ...          ...          ...
# 2045       -1.0        volvo       gas        std         four        sedan
# 2046       -1.0        volvo       gas      turbo         four        sedan
# 2047       -1.0        volvo       gas        std         four        sedan
# 2048       -1.0        volvo    diesel      turbo         four        sedan
# 2049       -1.0        volvo       gas      turbo         four        sedan
#
# ...

# %%
# shape-->to know the number of rows and columns

ad.shape
# Out:
# (2050, 25)

# %%
# to konw the statistical information of the dataset 

ad.describe()
# Out:
#         symboling   wheel-base       length        width       height  \
# count  250.000000  2050.000000  2050.000000  2050.000000  2050.000000
# mean    -1.120000    98.756585   174.049268    65.907805    53.724878
# std      0.325613     6.008536    12.310164     2.140487     2.438150
# min     -2.000000    86.600000   141.100000    60.300000    47.800000
# 25%     -1.000000    94.500000   166.300000    64.100000    52.000000
# 50%     -1.000000    97.000000   173.200000    65.500000    54.100000
# 75%     -1.000000   102.400000   183.100000    66.900000    55.500000
# max     -1.000000   120.900000   208.100000    72.300000    59.800000
#
#        curb-weight  engine-size         bore       stroke  compression-ratio  \
# count  2050.000000  2050.000000  2010.000000  2010.000000        1440.000000
# mean   2555.565854   126.907317     3.329751     3.255423          10.779306
# std     519.535431    41.551137     0.272925     0.316007           4.561555
# ...

# %%
#isna()--> is used to check the null values present in the dataset

ad.isna().sum()
# Out:
# symboling            1800
# car-name                0
# fuel-type               0
# aspiration              0
# num-of-doors           20
# body-style              0
# drive-wheels            0
# engine-location         0
# wheel-base              0
# length                  0
# width                   0
# height                  0
# curb-weight             0
# engine-type           120
# num-of-cylinders        0
# engine-size             0
# fuel-system             0
# bore                   40
# stroke                 40
# compression-ratio     610
# horsepower             20
# peak-rpm               20
# city-mpg                0
# highway-mpg             0
# price                  40
# dtype: int64

# %%
# notna()--> to list out all the notnull values in the dataset 

ad.notna().sum()
# Out:
# symboling             250
# car-name             2050
# fuel-type            2050
# aspiration           2050
# num-of-doors         2030
# body-style           2050
# drive-wheels         2050
# engine-location      2050
# wheel-base           2050
# length               2050
# width                2050
# height               2050
# curb-weight          2050
# engine-type          1930
# num-of-cylinders     2050
# engine-size          2050
# fuel-system          2050
# bore                 2010
# stroke               2010
# compression-ratio    1440
# horsepower           2030
# peak-rpm             2030
# city-mpg             2050
# highway-mpg          2050
# price                2010
# dtype: int64

# %%
# info()--> properties of the dataset

ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          250 non-null    float64
#  1   car-name           2050 non-null   object
#  2   fuel-type          2050 non-null   object
#  3   aspiration         2050 non-null   object
#  4   num-of-doors       2030 non-null   object
#  5   body-style         2050 non-null   object
#  6   drive-wheels       2050 non-null   object
#  7   engine-location    2050 non-null   object
#  8   wheel-base         2050 non-null   float64
#  9   length             2050 non-null   float64
#  10  width              2050 non-null   float64
#  11  height             2050 non-null   float64
#  12  curb-weight        2050 non-null   int64
#  13  engine-type        1930 non-null   object
#  14  num-of-cylinders   2050 non-null   object
#  15  engine-size        2050 non-null   int64
# ...

# %%
# type()--> knowing the datatype of the dataset

type(ad)
# Out:
# pandas.core.frame.DataFrame

# %%
#head()--> Displaying the top five data from the dataset,by default gives rows

ad.head()
# Out:
#    symboling     car-name fuel-type aspiration num-of-doors   body-style  \
# 0        NaN  alfa-romero       gas        std          two  convertible
# 1        NaN  alfa-romero       gas        std          two  convertible
# 2        NaN  alfa-romero       gas        std          two    hatchback
# 3        NaN         audi       gas        std         four        sedan
# 4        NaN         audi       gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# 3          fwd           front        99.8   176.6  ...          109
# 4          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm  city-mpg  \
# ...

# %%
#tail()--> Displaying the last five data from the dataset,by default gives rows 

ad.tail()
# Out:
#       symboling car-name fuel-type aspiration num-of-doors body-style  \
# 2045       -1.0    volvo       gas        std         four      sedan
# 2046       -1.0    volvo       gas      turbo         four      sedan
# 2047       -1.0    volvo       gas        std         four      sedan
# 2048       -1.0    volvo    diesel      turbo         four      sedan
# 2049       -1.0    volvo       gas      turbo         four      sedan
#
#      drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 2045          rwd           front       109.1   188.8  ...          141
# 2046          rwd           front       109.1   188.8  ...          141
# 2047          rwd           front       109.1   188.8  ...          173
# 2048          rwd           front       109.1   188.8  ...          145
# 2049          rwd           front       109.1   188.8  ...          141
#
#       fuel-system  bore stroke compression-ratio  horsepower peak-rpm  \
# ...

# %%
# drop()--> to delete the useless column in our dataset
# inplace=True --> permanently deletes the column from the dataset,by default it is false
# axis=0 --> defines the row 
# axis=1 --> defines the column

ad.drop(['symboling'],inplace=True,axis=1)

# %%
ad
# Out:
#          car-name fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0     alfa-romero       gas        std          two  convertible          rwd
# 1     alfa-romero       gas        std          two  convertible          rwd
# 2     alfa-romero       gas        std          two    hatchback          rwd
# 3            audi       gas        std         four        sedan          fwd
# 4            audi       gas        std         four        sedan          4wd
# ...           ...       ...        ...          ...          ...          ...
# 2045        volvo       gas        std         four        sedan          rwd
# 2046        volvo       gas      turbo         four        sedan          rwd
# 2047        volvo       gas        std         four        sedan          rwd
# 2048        volvo    diesel      turbo         four        sedan          rwd
# 2049        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
# value_counts()-->counts the number of repeated values in the particular column

ad['fuel-type'].value_counts()
# Out:
# gas       1850
# diesel     200
# Name: fuel-type, dtype: int64

# %%
# unique()--> fetches the unique values in particular column

ad['car-name'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# del(keyword)-->is used to delete the particular value from the dataset

# example:del DataFrame_Name['row number','column Number']

# %%
# type()-->to know the datatype of particular column
# if we pass single column to the type() it will always be of Series type

type(ad['car-name'])
# Out:
# pandas.core.series.Series

# %%
# if we pass more than one column in type() it will always be dataframe type

type(ad[['car-name','aspiration']])
# Out:
# pandas.core.frame.DataFrame

# %%
#dtypes keyword --> shows the datatype of each column in dataset

ad.dtypes
# Out:
# car-name              object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# keys()--> returns all the column names/indexes name

ad.keys()
# Out:
# Index(['car-name', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
#        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
# count()--> returns the  total number of values in each column in dataset

ad.count()
# Out:
# car-name             2050
# fuel-type            2050
# aspiration           2050
# num-of-doors         2030
# body-style           2050
# drive-wheels         2050
# engine-location      2050
# wheel-base           2050
# length               2050
# width                2050
# height               2050
# curb-weight          2050
# engine-type          1930
# num-of-cylinders     2050
# engine-size          2050
# fuel-system          2050
# bore                 2010
# stroke               2010
# compression-ratio    1440
# horsepower           2030
# peak-rpm             2030
# city-mpg             2050
# highway-mpg          2050
# price                2010
# dtype: int64

# %%
# groupby()--> splits the data acccording to the category
# count()--> counts the total number of values  

ad.groupby('car-name')['price'].count()
# Out:
# car-name
# alfa-romero       30
# audi              60
# bmw               80
# chevrolet         30
# dodge             90
# honda            130
# isuzu             20
# jaguar            30
# mazda            170
# mercedes-benz     80
# mercury           10
# mitsubishi       130
# nissan           180
# peugot           110
# plymouth          70
# porsche           40
# renault           20
# saab              60
# subaru           120
# toyota           320
# volkswagen       120
# volvo            110
# Name: price, dtype: int64

# %%
ad.isna().sum()
# Out:
# car-name               0
# fuel-type              0
# aspiration             0
# num-of-doors          20
# body-style             0
# drive-wheels           0
# engine-location        0
# wheel-base             0
# length                 0
# width                  0
# height                 0
# curb-weight            0
# engine-type          120
# num-of-cylinders       0
# engine-size            0
# fuel-system            0
# bore                  40
# stroke                40
# compression-ratio    610
# horsepower            20
# peak-rpm              20
# city-mpg               0
# highway-mpg            0
# price                 40
# dtype: int64

# %%
# Nmean=ad['normalized-losses'].mean()

# %%
# Nmean

# %%
# there were 41 null values in the normalized-losses column so we replaced them by the mean of that column

# ad['normalized-losses'].fillna(Nmean,inplace=True)

# %%
ad
# Out:
#          car-name fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0     alfa-romero       gas        std          two  convertible          rwd
# 1     alfa-romero       gas        std          two  convertible          rwd
# 2     alfa-romero       gas        std          two    hatchback          rwd
# 3            audi       gas        std         four        sedan          fwd
# 4            audi       gas        std         four        sedan          4wd
# ...           ...       ...        ...          ...          ...          ...
# 2045        volvo       gas        std         four        sedan          rwd
# 2046        volvo       gas      turbo         four        sedan          rwd
# 2047        volvo       gas        std         four        sedan          rwd
# 2048        volvo    diesel      turbo         four        sedan          rwd
# 2049        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2030 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        1930 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
# there were 2 null values in the num_of_door column so we replaced them by the mean of that column



ad['num-of-doors'].fillna('four',inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        1930 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
ad['engine-type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', nan, 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
ad['engine-type'].fillna('ohcv',inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
Bmean=ad['bore'].mean()

# %%
Bmean
# Out:
# 3.3297512437810797

# %%
ad['bore'].fillna(Bmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
Smean=ad['stroke'].mean()

# %%
Smean
# Out:
# 3.255422885572121

# %%
ad['stroke'].fillna(Smean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
Cmean=ad['compression-ratio'].mean()

# %%
Cmean
# Out:
# 10.779305555555531

# %%
ad['compression-ratio'].fillna(Cmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
Hmean=ad['horsepower'].mean()

# %%
Hmean
# Out:
# 104.25615763546799

# %%
ad['horsepower'].fillna(Cmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
PRmean=ad['peak-rpm'].mean()

# %%
PRmean
# Out:
# 5125.369458128079

# %%
ad['peak-rpm'].fillna(PRmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
Pmean=ad['price'].mean()

# %%
Pmean
# Out:
# 13207.129353233831

# %%
ad['price'].fillna(Pmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car-name           2050 non-null   object
#  1   fuel-type          2050 non-null   object
#  2   aspiration         2050 non-null   object
#  3   num-of-doors       2050 non-null   object
#  4   body-style         2050 non-null   object
#  5   drive-wheels       2050 non-null   object
#  6   engine-location    2050 non-null   object
#  7   wheel-base         2050 non-null   float64
#  8   length             2050 non-null   float64
#  9   width              2050 non-null   float64
#  10  height             2050 non-null   float64
#  11  curb-weight        2050 non-null   int64
#  12  engine-type        2050 non-null   object
#  13  num-of-cylinders   2050 non-null   object
#  14  engine-size        2050 non-null   int64
#  15  fuel-system        2050 non-null   object
# ...

# %%
ad.to_csv('New_Car_Automobile.csv')

# %%
# list()--> returns the name of each column of dataset in the form of list

list(ad)
# Out:
# ['car-name',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
# isnull()--> returns true if null value is present and false if no null values 
ad.isnull()
# Out:
#       car-name  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0        False      False       False         False       False         False
# 1        False      False       False         False       False         False
# 2        False      False       False         False       False         False
# 3        False      False       False         False       False         False
# 4        False      False       False         False       False         False
# ...        ...        ...         ...           ...         ...           ...
# 2045     False      False       False         False       False         False
# 2046     False      False       False         False       False         False
# 2047     False      False       False         False       False         False
# 2048     False      False       False         False       False         False
# 2049     False      False       False         False       False         False
#
# ...

# %%
# sum()--> returns the total number of null present in each column

ad.isnull().sum()
# Out:
# car-name             0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
ad
# Out:
#          car-name fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0     alfa-romero       gas        std          two  convertible          rwd
# 1     alfa-romero       gas        std          two  convertible          rwd
# 2     alfa-romero       gas        std          two    hatchback          rwd
# 3            audi       gas        std         four        sedan          fwd
# 4            audi       gas        std         four        sedan          4wd
# ...           ...       ...        ...          ...          ...          ...
# 2045        volvo       gas        std         four        sedan          rwd
# 2046        volvo       gas      turbo         four        sedan          rwd
# 2047        volvo       gas        std         four        sedan          rwd
# 2048        volvo    diesel      turbo         four        sedan          rwd
# 2049        volvo       gas      turbo         four        sedan          rwd
#
# ...
