# %%
# importing libraries for EDA

import pandas as pd
import numpy as np

# %%
# loading data into dataframe

# sep='separator_symbol'--> it separates the data with the help of seperator symbol

ad=pd.read_csv('Automobile_data.csv')

# %%
# displaying the data

ad
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0          NaN                NaN  alfa-romero       gas        std
# 1          NaN                NaN  alfa-romero       gas        std
# 2          NaN                NaN  alfa-romero       gas        std
# 3          NaN              164.0         audi       gas        std
# 4          NaN              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200       -1.0               95.0        volvo       gas        std
# 201       -1.0               95.0        volvo       gas      turbo
# 202       -1.0               95.0        volvo       gas        std
# 203       -1.0               95.0        volvo    diesel      turbo
# 204       -1.0               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               NaN      111.0
# 1            130         mpfi  3.47    2.68               NaN      111.0
# 2            152         mpfi  2.68    3.47               NaN      154.0
# 3            109         mpfi  3.19    3.40              10.0      102.0
# 4            136         mpfi  3.19    3.40               NaN      115.0
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5      114.0
# 201          141         mpfi  3.78    3.15               8.7      160.0
# 202          173         mpfi  3.58    2.87               8.8      134.0
# 203          145          idi  3.01    3.40              23.0      106.0
# 204          141         mpfi  3.78    3.15               9.5      114.0
#
#      peak-rpm city-mpg  highway-mpg    price
# 0      5000.0       21           27  13495.0
# 1      5000.0       21           27  16500.0
# 2      5000.0       19           26  16500.0
# 3      5500.0       24           30  13950.0
# 4      5500.0       18           22  17450.0
# ..        ...      ...          ...      ...
# 200    5400.0       23           28  16845.0
# 201    5300.0       19           25  19045.0
# 202    5500.0       18           23  21485.0
# 203    4800.0       26           27  22470.0
# 204    5400.0       19           25  22625.0
#
# [205 rows x 26 columns]

# %%
# shape-->to know the number of rows and columns

ad.shape
# Out:
# (205, 26)

# %%
# to konw the statistical information of the dataset 

ad.describe()
# Out:
#        symboling  normalized-losses  wheel-base      length       width  \
# count  25.000000         164.000000  205.000000  205.000000  205.000000
# mean   -1.120000         122.000000   98.756585  174.049268   65.907805
# std     0.331662          35.442168    6.021776   12.337289    2.145204
# min    -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%    -1.000000          94.000000   94.500000  166.300000   64.100000
# 50%    -1.000000         115.000000   97.000000  173.200000   65.500000
# 75%    -1.000000         150.000000  102.400000  183.100000   66.900000
# max    -1.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2145.000000    97.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2935.000000   141.000000    3.590000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         144.000000  203.000000   203.000000  205.000000   205.000000
# mean           10.779306  104.256158  5125.369458   25.219512    30.751220
# std             4.575887   39.714369   479.334560    6.542142     6.886443
# min             7.500000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.575000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.300000   95.000000  5200.000000   24.000000    30.000000
# 75%             9.500000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  288.000000  6600.000000   49.000000    54.000000
#
#               price
# count    201.000000
# mean   13207.129353
# std     7947.066342
# min     5118.000000
# 25%     7775.000000
# 50%    10295.000000
# 75%    16500.000000
# max    45400.000000

# %%
#isna()--> is used to check the null values present in the dataset

ad.isna().sum()
# Out:
# symboling            180
# normalized-losses     41
# make                   0
# fuel-type              0
# aspiration             0
# num-of-doors           2
# body-style             0
# drive-wheels           0
# engine-location        0
# wheel-base             0
# length                 0
# width                  0
# height                 0
# curb-weight            0
# engine-type           12
# num-of-cylinders       0
# engine-size            0
# fuel-system            0
# bore                   4
# stroke                 4
# compression-ratio     61
# horsepower             2
# peak-rpm               2
# city-mpg               0
# highway-mpg            0
# price                  4
# dtype: int64

# %%
# notna()--> to list out all the notnull values in the dataset 

ad.notna().sum()
# Out:
# symboling             25
# normalized-losses    164
# make                 205
# fuel-type            205
# aspiration           205
# num-of-doors         203
# body-style           205
# drive-wheels         205
# engine-location      205
# wheel-base           205
# length               205
# width                205
# height               205
# curb-weight          205
# engine-type          193
# num-of-cylinders     205
# engine-size          205
# fuel-system          205
# bore                 201
# stroke               201
# compression-ratio    144
# horsepower           203
# peak-rpm             203
# city-mpg             205
# highway-mpg          205
# price                201
# dtype: int64

# %%
# info()--> properties of the dataset

ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  164 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       203 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        193 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               201 non-null    float64
#  18  stroke             201 non-null    float64
#  19  compression-ratio  144 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
# type()--> knowing the datatype of the dataset

type(ad)
# Out:
# pandas.core.frame.DataFrame

# %%
#head()--> Displaying the top five data from the dataset,by default gives rows

ad.head()
# Out:
#    normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                NaN  alfa-romero       gas        std          two
# 1                NaN  alfa-romero       gas        std          two
# 2                NaN  alfa-romero       gas        std          two
# 3              164.0         audi       gas        std         four
# 4              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# 0          130         mpfi  3.47   2.68               NaN       111.0
# 1          130         mpfi  3.47   2.68               NaN       111.0
# 2          152         mpfi  2.68   3.47               NaN       154.0
# 3          109         mpfi  3.19   3.40              10.0       102.0
# 4          136         mpfi  3.19   3.40               NaN       115.0
#
#   peak-rpm  city-mpg  highway-mpg    price
# 0   5000.0        21           27  13495.0
# 1   5000.0        21           27  16500.0
# 2   5000.0        19           26  16500.0
# 3   5500.0        24           30  13950.0
# 4   5500.0        18           22  17450.0
#
# [5 rows x 25 columns]

# %%
#tail()--> Displaying the last five data from the dataset,by default gives rows 

ad.tail()
# Out:
#      normalized-losses   make fuel-type aspiration num-of-doors body-style  \
# 200               95.0  volvo       gas        std         four      sedan
# 201               95.0  volvo       gas      turbo         four      sedan
# 202               95.0  volvo       gas        std         four      sedan
# 203               95.0  volvo    diesel      turbo         four      sedan
# 204               95.0  volvo       gas      turbo         four      sedan
#
#     drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 200          rwd           front       109.1   188.8  ...          141
# 201          rwd           front       109.1   188.8  ...          141
# 202          rwd           front       109.1   188.8  ...          173
# 203          rwd           front       109.1   188.8  ...          145
# 204          rwd           front       109.1   188.8  ...          141
#
#      fuel-system  bore stroke compression-ratio  horsepower peak-rpm  \
# 200         mpfi  3.78   3.15               9.5       114.0   5400.0
# 201         mpfi  3.78   3.15               8.7       160.0   5300.0
# 202         mpfi  3.58   2.87               8.8       134.0   5500.0
# 203          idi  3.01   3.40              23.0       106.0   4800.0
# 204         mpfi  3.78   3.15               9.5       114.0   5400.0
#
#      city-mpg  highway-mpg    price
# 200        23           28  16845.0
# 201        19           25  19045.0
# 202        18           23  21485.0
# 203        26           27  22470.0
# 204        19           25  22625.0
#
# [5 rows x 25 columns]

# %%
# drop()--> to delete the useless column in our dataset
# inplace=True --> permanently deletes the column from the dataset,by default it is false
# axis=0 --> defines the row 
# axis=1 --> defines the column

ad.drop(['symboling'],inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-76cefb6b1658> in <module>
#       4 # axis=1 --> defines the column
#       5
# ----> 6 ad.drop(['symboling'],inplace=True,axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['symboling'] not found in axis"

# %%
ad
# Out:
#      normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                  NaN  alfa-romero       gas        std          two
# 1                  NaN  alfa-romero       gas        std          two
# 2                  NaN  alfa-romero       gas        std          two
# 3                164.0         audi       gas        std         four
# 4                164.0         audi       gas        std         four
# ..                 ...          ...       ...        ...          ...
# 200               95.0        volvo       gas        std         four
# 201               95.0        volvo       gas      turbo         four
# 202               95.0        volvo       gas        std         four
# 203               95.0        volvo    diesel      turbo         four
# 204               95.0        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0    convertible          rwd           front        88.6   168.8  ...
# 1    convertible          rwd           front        88.6   168.8  ...
# 2      hatchback          rwd           front        94.5   171.2  ...
# 3          sedan          fwd           front        99.8   176.6  ...
# 4          sedan          4wd           front        99.4   176.6  ...
# ..           ...          ...             ...         ...     ...  ...
# 200        sedan          rwd           front       109.1   188.8  ...
# 201        sedan          rwd           front       109.1   188.8  ...
# 202        sedan          rwd           front       109.1   188.8  ...
# 203        sedan          rwd           front       109.1   188.8  ...
# 204        sedan          rwd           front       109.1   188.8  ...
#
#      engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# 0            130         mpfi  3.47   2.68               NaN       111.0
# 1            130         mpfi  3.47   2.68               NaN       111.0
# 2            152         mpfi  2.68   3.47               NaN       154.0
# 3            109         mpfi  3.19   3.40              10.0       102.0
# 4            136         mpfi  3.19   3.40               NaN       115.0
# ..           ...          ...   ...    ...               ...         ...
# 200          141         mpfi  3.78   3.15               9.5       114.0
# 201          141         mpfi  3.78   3.15               8.7       160.0
# 202          173         mpfi  3.58   2.87               8.8       134.0
# 203          145          idi  3.01   3.40              23.0       106.0
# 204          141         mpfi  3.78   3.15               9.5       114.0
#
#     peak-rpm  city-mpg  highway-mpg    price
# 0     5000.0        21           27  13495.0
# 1     5000.0        21           27  16500.0
# 2     5000.0        19           26  16500.0
# 3     5500.0        24           30  13950.0
# 4     5500.0        18           22  17450.0
# ..       ...       ...          ...      ...
# 200   5400.0        23           28  16845.0
# 201   5300.0        19           25  19045.0
# 202   5500.0        18           23  21485.0
# 203   4800.0        26           27  22470.0
# 204   5400.0        19           25  22625.0
#
# [205 rows x 25 columns]

# %%
# value_counts()-->counts the number of repeated values in the particular column

ad['fuel-type'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
# unique()--> fetches the unique values in particular column

ad['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# del(keyword)-->is used to delete the particular value from the dataset

# example:del DataFrame_Name['row number','column Number']

# %%
# type()-->to know the datatype of particular column
# if we pass single column to the type() it will always be of Series type

type(ad['make'])
# Out:
# pandas.core.series.Series

# %%
# if we pass more than one column in type() it will always be dataframe type

type(ad[['make','aspiration']])
# Out:
# pandas.core.frame.DataFrame

# %%
#dtypes keyword --> shows the datatype of each column in dataset

ad.dtypes
# Out:
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# keys()--> returns all the column names/indexes name

ad.keys()
# Out:
# Index(['normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
# count()--> returns the  total number of values in each column in dataset

ad.count()
# Out:
# normalized-losses    164
# make                 205
# fuel-type            205
# aspiration           205
# num-of-doors         203
# body-style           205
# drive-wheels         205
# engine-location      205
# wheel-base           205
# length               205
# width                205
# height               205
# curb-weight          205
# engine-type          193
# num-of-cylinders     205
# engine-size          205
# fuel-system          205
# bore                 201
# stroke               201
# compression-ratio    144
# horsepower           203
# peak-rpm             203
# city-mpg             205
# highway-mpg          205
# price                201
# dtype: int64

# %%
# groupby()--> splits the data acccording to the category
# count()--> counts the total number of values  

ad.groupby('make')['price'].count()
# Out:
# make
# alfa-romero       3
# audi              6
# bmw               8
# chevrolet         3
# dodge             9
# honda            13
# isuzu             2
# jaguar            3
# mazda            17
# mercedes-benz     8
# mercury           1
# mitsubishi       13
# nissan           18
# peugot           11
# plymouth          7
# porsche           4
# renault           2
# saab              6
# subaru           12
# toyota           32
# volkswagen       12
# volvo            11
# Name: price, dtype: int64

# %%
ad.isna().sum()
# Out:
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type          12
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio    61
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
Nmean=ad['normalized-losses'].mean()

# %%
Nmean
# Out:
# 122.0

# %%
# there were 41 null values in the normalized-losses column so we replaced them by the mean of that column

ad['normalized-losses'].fillna(Nmean,inplace=True)

# %%
ad
# Out:
#      normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                122.0  alfa-romero       gas        std          two
# 1                122.0  alfa-romero       gas        std          two
# 2                122.0  alfa-romero       gas        std          two
# 3                164.0         audi       gas        std         four
# 4                164.0         audi       gas        std         four
# ..                 ...          ...       ...        ...          ...
# 200               95.0        volvo       gas        std         four
# 201               95.0        volvo       gas      turbo         four
# 202               95.0        volvo       gas        std         four
# 203               95.0        volvo    diesel      turbo         four
# 204               95.0        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0    convertible          rwd           front        88.6   168.8  ...
# 1    convertible          rwd           front        88.6   168.8  ...
# 2      hatchback          rwd           front        94.5   171.2  ...
# 3          sedan          fwd           front        99.8   176.6  ...
# 4          sedan          4wd           front        99.4   176.6  ...
# ..           ...          ...             ...         ...     ...  ...
# 200        sedan          rwd           front       109.1   188.8  ...
# 201        sedan          rwd           front       109.1   188.8  ...
# 202        sedan          rwd           front       109.1   188.8  ...
# 203        sedan          rwd           front       109.1   188.8  ...
# 204        sedan          rwd           front       109.1   188.8  ...
#
#      engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# 0            130         mpfi  3.47   2.68               NaN       111.0
# 1            130         mpfi  3.47   2.68               NaN       111.0
# 2            152         mpfi  2.68   3.47               NaN       154.0
# 3            109         mpfi  3.19   3.40              10.0       102.0
# 4            136         mpfi  3.19   3.40               NaN       115.0
# ..           ...          ...   ...    ...               ...         ...
# 200          141         mpfi  3.78   3.15               9.5       114.0
# 201          141         mpfi  3.78   3.15               8.7       160.0
# 202          173         mpfi  3.58   2.87               8.8       134.0
# 203          145          idi  3.01   3.40              23.0       106.0
# 204          141         mpfi  3.78   3.15               9.5       114.0
#
#     peak-rpm  city-mpg  highway-mpg    price
# 0     5000.0        21           27  13495.0
# 1     5000.0        21           27  16500.0
# 2     5000.0        19           26  16500.0
# 3     5500.0        24           30  13950.0
# 4     5500.0        18           22  17450.0
# ..       ...       ...          ...      ...
# 200   5400.0        23           28  16845.0
# 201   5300.0        19           25  19045.0
# 202   5500.0        18           23  21485.0
# 203   4800.0        26           27  22470.0
# 204   5400.0        19           25  22625.0
#
# [205 rows x 25 columns]

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       203 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        193 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               201 non-null    float64
#  18  stroke             201 non-null    float64
#  19  compression-ratio  144 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
# there were 2 null values in the num_of_door column so we replaced them by the mean of that column



ad['num-of-doors'].fillna('four',inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        193 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               201 non-null    float64
#  18  stroke             201 non-null    float64
#  19  compression-ratio  144 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
ad['engine-type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', nan, 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
ad['engine-type'].fillna('ohcv',inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               201 non-null    float64
#  18  stroke             201 non-null    float64
#  19  compression-ratio  144 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
Bmean=ad['bore'].mean()

# %%
Bmean
# Out:
# 3.3297512437810957

# %%
ad['bore'].fillna(Bmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               205 non-null    float64
#  18  stroke             201 non-null    float64
#  19  compression-ratio  144 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
Smean=ad['stroke'].mean()

# %%
Smean
# Out:
# 3.2554228855721337

# %%
ad['stroke'].fillna(Smean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               205 non-null    float64
#  18  stroke             205 non-null    float64
#  19  compression-ratio  144 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
Cmean=ad['compression-ratio'].mean()

# %%
Cmean
# Out:
# 10.779305555555553

# %%
ad['compression-ratio'].fillna(Cmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               205 non-null    float64
#  18  stroke             205 non-null    float64
#  19  compression-ratio  205 non-null    float64
#  20  horsepower         203 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
Hmean=ad['horsepower'].mean()

# %%
Hmean
# Out:
# 104.25615763546799

# %%
ad['horsepower'].fillna(Cmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               205 non-null    float64
#  18  stroke             205 non-null    float64
#  19  compression-ratio  205 non-null    float64
#  20  horsepower         205 non-null    float64
#  21  peak-rpm           203 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
PRmean=ad['peak-rpm'].mean()

# %%
PRmean
# Out:
# 5125.369458128079

# %%
ad['peak-rpm'].fillna(PRmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               205 non-null    float64
#  18  stroke             205 non-null    float64
#  19  compression-ratio  205 non-null    float64
#  20  horsepower         205 non-null    float64
#  21  peak-rpm           205 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              201 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB

# %%
Pmean=ad['price'].mean()

# %%
Pmean
# Out:
# 13207.129353233831

# %%
ad['price'].fillna(Pmean,inplace=True)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  205 non-null    float64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
#  16  fuel-system        205 non-null    object
#  17  bore               205 non-null    float64
#  18  stroke             205 non-null    float64
#  19  compression-ratio  205 non-null    float64
#  20  horsepower         205 non-null    float64
#  21  peak-rpm           205 non-null    float64
#  22  city-mpg           205 non-null    int64
#  23  highway-mpg        205 non-null    int64
#  24  price              205 non-null    float64
# dtypes: float64(11), int64(4), object(10)
# memory usage: 40.2+ KB
